# %% [markdown]
# # Explore the Data

# %% [markdown]
# Let us build some intuition around the Loan Data

# %%
#Load the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Default Variables
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,9)
plt.rcParams['font.size'] = 18
plt.style.use('fivethirtyeight')
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
#Load the dataset
df = pd.read_csv("data/loan_data_clean.csv")

# %%
df.head()
# Out:
#    default  amount  interest grade  years ownership   income  age
# 0        0    5000     10.65     B  10.00      RENT 24000.00   33
# 1        0    2400     10.99     C  25.00      RENT 12252.00   31
# 2        0   10000     13.49     C  13.00      RENT 49200.00   24
# 3        0    5000     10.99     A   3.00      RENT 36000.00   39
# 4        0    3000     10.99     E   9.00      RENT 48000.00   24

# %%
# create the target "amount * default'
df['amount_with_default'] = df.amount * (1- df.default)

# %%
df.head()
# Out:
#    default  amount  interest grade  years ownership   income  age  \
# 0        0    5000     10.65     B  10.00      RENT 24000.00   33
# 1        0    2400     10.99     C  25.00      RENT 12252.00   31
# 2        0   10000     13.49     C  13.00      RENT 49200.00   24
# 3        0    5000     10.99     A   3.00      RENT 36000.00   39
# 4        0    3000     10.99     E   9.00      RENT 48000.00   24
#
#    amount_with_default
# 0                 5000
# 1                 2400
# 2                10000
# 3                 5000
# 4                 3000

# %% [markdown]
# ## Single Variable Exploration

# %%
# Create histogram for the target variable

# %%
# Explore other variables

# %% [markdown]
# ##  Dual Variable Exploration

# %%
# Create a crosstab of grade and ownership

# %% [markdown]
# ### Explore the impact of `age`  with `amount_non_default`

# %% [markdown]
# ### Explore the impact of `interest` with `amount_non_default`

# %% [markdown]
# ### Explore the impact of `income` with `amount_non_default`

# %%
plt.hist(df.income, bins=100)
plt.ylim(0,20)
# Out:
# (0, 20)

# %%
sns.distplot(df.income)
# Out:
# /Users/amitkaps/miniconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
df['income_log'] = np.log(df.income)

# %%
sns.distplot(df.income_log)
# Out:
# /Users/amitkaps/miniconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
plt.scatter(x=df.income, y=df.amount_with_default)

# %%
# Transform the income variable

# %%
# Plot the transformed variable
plt.scatter(x=df.income_log, y=df.amount_with_default, alpha=0.2)

# %%
# ?plt.hexbin

# %%
plt.hexbin(x=df.income_log, y=df.amount_with_default, gridsize = 30,
           alpha=0.8, cmap=plt.cm.viridis)

# %% [markdown]
# ### Explore the impact of `years` with `amount_non_default`

# %%
plt.scatter(x=df.years, y=df.amount_with_default, alpha=0.4)

# %% [markdown]
# ### Explore the impact of `grade` with `amount_non_default`

# %%
sns.stripplot(x='grade', y='amount_with_default', data=df, jitter=True, alpha=0.5)

# %% [markdown]
# ## Three Variable Exploration

# %% [markdown]
# ### Explore the relationship between `age`, `income` and `amount_non_default`

# %%
plt.scatter(x=df.age, y=df.amount_with_default, c=df.income, s=50, alpha=0.4,
           cmap=plt.cm.plasma)

# %%
plt.scatter(x=df.age, y=df.amount_with_default, c=df.income, s=df.years, alpha=0.4,
           cmap=plt.cm.plasma)

# %%
sns.pairplot(df)

# %% [markdown]
# ### Explore the relationship between plot `age`, `grade` and `amount_non_default`

# %%
sns.lmplot(x="age", y="amount_with_default", hue="grade", data=df, col='grade', col_wrap=2)

# %%
# ?sns.lmplot
